# %%
# Imports
from pathlib import Path
from data_processing.dot_env import config
import pandas as pd

# %%
id_numbers = [423]

# %%
maybe_input = config.get("INPUT_DATA_FOLDER")
INPUT_DATA_FOLDER = Path(
    maybe_input if maybe_input is not None else "fix_input"
)
OUTPUT_DATA_FOLDER = Path.home() / "Desktop"

# %%
ids = [f"ID-{number}" for number in id_numbers]
experiment_data = {
    id: {
        "input_path": INPUT_DATA_FOLDER / id / "raw_data" / "RAW",
        "output_path": OUTPUT_DATA_FOLDER / "Sergey Converted Raw Data" / id
    } for id in ids
}

# %%
for data_dict in experiment_data.values():
    output_path = data_dict['output_path']
    output_path.mkdir(parents=True, exist_ok=True)

# %%
dataframes = {}
for id, data_dict in experiment_data.items():
    input_path = data_dict['input_path']
    df = pd.read_parquet(path=input_path)
    data_dict['dataframe'] = df

# %%
# turn samples into lists (numpy vector?)
for id, data_dict in experiment_data.items():
    df = data_dict['dataframe']
    # get samples columns only

# %%
# define processing
def

# %%
# parallel process samples

# %%
# add to dataframe
